# %% [markdown]
# # NeuroMANCER: System ID Tutorial
#
# This notebook outlines the basic structure of a training script for system identification with deep state space models.
#
# We begin by importing the necessary components from NeuroMANCER, as well as specifying some hyperparameters used to define the structure and optimization of our model:

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
import slim
import psl

from neuromancer import blocks, estimators, dynamics, arg
from neuromancer.activations import activations
from neuromancer.visuals import VisualizerOpen
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.constraint import Objective
from neuromancer.simulators import OpenLoopSimulator, MultiSequenceOpenLoopSimulator
from neuromancer.callbacks import SysIDCallback
from neuromancer.loggers import BasicLogger, MLFlowLogger
from neuromancer.dataset import read_file, normalize_data, split_sequence_data, SequenceDataset
from neuromancer.constraint import Variable


# params for configuration
params = {
    "nsteps": 32,             # Prediction horizon length.
    "nsim": 10000,            # Number of temporal datapoints in the simulated dataset.
    "data_seed": 408,         # Random seed for the dataset emulator.
    "norm": ["U", "D", "Y"],  # Norms imposed on raw variables. U: inputs, D: disturbances, Y: outputs.
    "Q_y": 1.0,               # Output tracking penalty weight.
    "Q_e": 1.0,               # State estimator hidden prediction penalty weight.
    "Q_sub": 1.0,             # Linear maps regularization weight.
    "Q_con_x": 1.0,           # Hidden state constraints penalty weight.
    "Q_dx": 0.1,              # Penalty weight on hidden state difference in one time step. 
    "savedir": "test",        # Where should your trained model and plots be saved (temp).
    "eval_metric": "loop_dev_ref_loss",   # Metric for model selection and early stopping.
    "metrics": ["nstep_dev_loss", "loop_dev_loss", "best_loop_dev_loss",
               "nstep_dev_ref_loss", "loop_dev_ref_loss"],   # Metrics to be logged.
    "epochs": 300,            # Number of training epochs.
    "lr": 0.001,              # Learning rate.
    "patience": 100,          # Early stopping patience.
    "warmup": 10,             # Early stopping warmup.
}
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Datasets
# NeuroMANCER currently supports both static and emulated datasets (generated from governing equations for various systems) via [PSL](https://github.com/pnnl/psl). Here, we define get_sequence_dataloaders() function for generating dataloader from the raw  data given as dictionary.
# For more details see datasets tutorial.

# %%
def get_sequence_dataloaders(
    data, nsteps, moving_horizon=False, norm_type="zero-one", split_ratio=None, num_workers=0,
):
    """This will generate dataloaders and open-loop sequence dictionaries for a given dictionary of
    data. Dataloaders are hard-coded for full-batch training to match NeuroMANCER's original
    training setup.

    :param data: (dict str: np.array or list[dict str: np.array]) data dictionary or list of data
        dictionaries; if latter is provided, multi-sequence datasets are created and splits are
        computed over the number of sequences rather than their lengths.
    :param nsteps: (int) length of windowed subsequences for N-step training.
    :param moving_horizon: (bool) whether to use moving horizon batching.
    :param norm_type: (str) type of normalization; see function `normalize_data` for more info.
    :param split_ratio: (list float) percentage of data in train and development splits; see
        function `split_sequence_data` for more info.
    """

    data, _ = normalize_data(data, norm_type)
    train_data, dev_data, test_data = split_sequence_data(data, nsteps, split_ratio)

    train_data = SequenceDataset(
        train_data,
        nsteps=nsteps,
        moving_horizon=moving_horizon,
        name="train",
    )
    dev_data = SequenceDataset(
        dev_data,
        nsteps=nsteps,
        moving_horizon=moving_horizon,
        name="dev",
    )
    test_data = SequenceDataset(
        test_data,
        nsteps=nsteps,
        moving_horizon=moving_horizon,
        name="test",
    )

    train_loop = train_data.get_full_sequence()
    dev_loop = dev_data.get_full_sequence()
    test_loop = test_data.get_full_sequence()

    train_data = DataLoader(
        train_data,
        batch_size=len(train_data),
        shuffle=False,
        collate_fn=train_data.collate_fn,
        num_workers=num_workers,
    )
    dev_data = DataLoader(
        dev_data,
        batch_size=len(dev_data),
        shuffle=False,
        collate_fn=dev_data.collate_fn,
        num_workers=num_workers,
    )
    test_data = DataLoader(
        test_data,
        batch_size=len(test_data),
        shuffle=False,
        collate_fn=test_data.collate_fn,
        num_workers=num_workers,
    )

    return (train_data, dev_data, test_data), (train_loop, dev_loop, test_loop), train_data.dataset.dims

# %%
# load dictionary dataset with raw data
# for available systems in PSL library check: psl.systems.keys()
# for available datasets in PSL library check: psl.datasets.keys()

system = 'aero'         # keyword of selected system

#  load raw dataset
if system in psl.emulators:
    data = psl.emulators[system](nsim=nsim, ninit=0, seed=args.data_seed).simulate()
elif system in psl.datasets:
    data = read_file(psl.datasets[system])
else:
    data = read_file(system)

# %% [markdown]
# Processed dataset format:
# nsim = number of time steps in the dataset time series
# nsteps = legth of the prediction horizon
# Y = observed outputs
# U = inputs
# D = disturbances
# Yp = past trajectories generated as Y[0:-nsteps]
# Yf = future trajectories generated as Y[nesteps:]
# data format in dataset dictionaries: train_data['key']: torch.Size([batch size (prediction horizon), number of batches, number of variables])

# %%
#  Train, Development, Test sets - nstep and loop format
nstep_data, loop_data, dims = get_sequence_dataloaders(data, params['nsteps'])
train_data, dev_data, test_data = nstep_data
train_loop, dev_loop, test_loop = loop_data

# input, output dimensions
nu = dims['U'][1]
ny = dims['Y'][1]

# %% [markdown]
# ## State Estimator
#
# To generate initial states during $N$-step training, we make use of state estimators which use the past outputs of the system to estimate the next state variable. NeuroMANCER provides a host of parametric state estimators for this purpose; in this case, we'll use a fully connected neural network. Each state estimator in neuromancer.estimators represents more generic component class representing arbitrary nn.Module with input_keys and output_keys for mapping neuromancer variabels.
# For more details see components and constraints tutorials.

# %%
activation = activations['relu']
linmap = slim.maps['linear']

nx = 90  # size of the latent variables
estimator = estimators.MLPEstimator(
    {**dims, "x0": (nx,)},
    nsteps=params['nsteps'],  # future window Nf
    window_size=params['nsteps'],  # past window Np <= Nf
    bias=True,
    linear_map=linmap,
    nonlin=activation,
    hsizes=[90, 120, 90],
    input_keys=["Yp"],
    linargs={},
    name='estimator',
)

# input output keys of the estimator 
print(estimator.input_keys)
print(estimator.output_keys)

# dynamics_model mapping of input keys to output keys
print(estimator)
# x0 = estimator(Yp)
# x0: initial values of latent variables estimated from time lagged outputs Yp
# Out:
# ['Yp']
# ['x0_estimator', 'reg_error_estimator']
# estimator(Yp) -> x0_estimator, reg_error_estimator

# %% [markdown]
# ## State Space Model
#
# Next, we define our block-structured state space model (SSM) as neuromancer component. These models divide system dynamics into separate functional components to decouple the behaviors of inputs, state transitions, and outputs. Using the `BlockSSM` constructor, we can build SSMs with arbitrary components, each with their own nonlinearities and structured weight parameterizations.
# For more details on how to construct arbitrary acyclic computational graphs with see components tutorial.

# %%
# define blocks
fx = blocks.RNN(nx, nx, linear_map=linmap,
                nonlin=activations['softexp'], hsizes=[60, 60])
linargs = {"sigma_min": 0.5, "sigma_max": 1.0}
fy = slim.maps['softSVD'](nx, ny, linargs=linargs)
fu = blocks.MLP(nu, nx, hsizes=[60, 60]) if nu != 0 else None

# define state space model
dynamics_model = dynamics.BlockSSM(fx, fy, fu=fu, name='dynamics', xou=torch.add,
                                   input_key_map={"x0": f"x0_{estimator.name}"})

# input output keys of the SSM 
print(dynamics_model.input_keys)
print(dynamics_model.output_keys)

# dynamics_model mapping of input keys to output keys
print(dynamics_model)
# Yf = dynamics_model(x0, Uf)
# Uf: future control actions
# Yf: predicted outputs
# Out:
# ['Uf', 'Yf', 'x0_estimator']
# ['fU_dynamics', 'X_pred_dynamics', 'Y_pred_dynamics', 'reg_error_dynamics']
# dynamics(Uf, Yf, x0_estimator) -> fU_dynamics, X_pred_dynamics, Y_pred_dynamics, reg_error_dynamics

# %% [markdown]
# ## Neuromancer Variables
# Here we leverage Neuromancer's variable abstraction for intuitive high-level definition of objective temrs and constraints. Each variable has assigned uniqye name that either exists as a key in the dataset dictionary (e.g., "Yf"), or is listed as output key in one of our components.

# %%
# bounds
xmin = -0.2
xmax = 1.2
dxudmin = -0.5
dxudmax = 0.5

# loss terms and constraints definition via variable class: neuromancer variable declaration
yhat = Variable(f"Y_pred_{dynamics_model.name}")
y = Variable("Yf")
x0 = Variable(f"x0_{estimator.name}")
xhat = Variable(f"X_pred_{dynamics_model.name}")
est_reg = Variable(f"reg_error_{estimator.name}")
dyn_reg = Variable(f"reg_error_{dynamics_model.name}")

# %% [markdown]
# ## Objective Terms
# To optimize the weights of our model, we first use mean-squared error as our objective to minimize the error between ground-truth observables and those predicted by our SSM. We additionally impose a loss on the estimator that ensures its state predictions align with ground-truth state observations. Further we add state smoothening penalty, and regularizations terms imposed on the model weights.
#
# In addition to minimizing the mean-squared error of predicted and expected observables, we may also want to impose further constraints on different model components to enforce certain model behaviors. Our first constraint will ensure the smoothness of state transitions by minimizing the mean-squared error between consecutive state predictions. Our second and third constraints impose lower and upper bounds on output observations, specifically the interval $[-0.2, 1.2]$.
#
# For more details see constraints tutorial.

# %%
# define loss function terms
reference_loss = params['Q_y']*((yhat == y)^2)
estimator_loss = params['Q_e']*((x0[1:] == xhat[-1, :-1, :])^2)
state_smoothing = params['Q_dx']*((xhat[1:] == xhat[:-1])^2)
regularization = params['Q_sub']*((est_reg + dyn_reg == 0)^2)
# define constraints
observation_lower_bound_penalty = params['Q_con_x']*(yhat > xmin)
observation_upper_bound_penalty = params['Q_con_x']*(yhat < xmax)
# custom loss and constraints names used as metrics
reference_loss.name = "ref_loss"
estimator_loss.name = "arrival_cost"
regularization.name = "reg_error"
observation_lower_bound_penalty.name = "y_low_bound_error"
observation_upper_bound_penalty.name = "y_up_bound_error"

# %% [markdown]
# ## Putting It All Together
#
# Having defined our model components, objective terms, and constraints, we can now combine each into an optimization problem using NeuroMANCER's `Problem` class. This will produce our final model, connecting all of the underlying components necessary to process our data, generate predictions, and optimize the model components.

# %%
# list of objectives and constraints
objectives = [regularization, reference_loss, estimator_loss]
constraints = [
    state_smoothing,
    observation_lower_bound_penalty,
    observation_upper_bound_penalty,
]
# list of components
components = [estimator, dynamics_model]
# constrained optimization problem = objectives + constraints + components
model = Problem(objectives, constraints, components)
model = model.to(device)

# %% [markdown]
# ## Training Our Model
#
# For training models, NeuroMANCER provides a `Trainer` class which encapsulates all of the training and evaluation logic necessary for $N$-step training, and additionally provides options for experiment logging, visualization, and roll-out simulation in the loop. To get started, we instantiate PyTorch's AdamW optimizer with our model's parameters. We then provide some components which are specific to the NeuroMANCER training regime:
#
# * The `OpenLoopSimulator` is used to simulate a full roll-out of the SSM starting from a single initial state. Unlike the $N$-step simulation used during training, this is meant to evaluate the performance of the model in a free-running manner rather than over short windows of time.
# * The `BasicLogger` is used to output user-specified metrics during training and evaluation. It also handles saving model checkpoints.
# * The `VisualizerOpen` class generates plots showing predicted vs. ground-truth outputs for both $N$-step and open-loop model simulations, providing a useful visual assessment of model performance.
#
# With all of these components defined, we can then instantiate our `Trainer` class. We provide the model and dataset, the optimizer, and the aforementioned helper components. We additionally specify the number of epochs, an evaluation metric used to determine the best-performing model, and a patience value; this latter value determines how many epochs should be completed without any improvement in the evaluation metric before discontinuing training in order to avoid overfitting and wasted computation.

# %%
# define callback
simulator = OpenLoopSimulator(
    model, train_loop, dev_loop, test_loop, eval_sim=True, device=device,
) if isinstance(train_loop, dict) else MultiSequenceOpenLoopSimulator(
    model, train_loop, dev_loop, test_loop, eval_sim=True, device=device,
)
visualizer = VisualizerOpen(
    dynamics_model,
    1,
    params['savedir'],
    training_visuals=False,
    trace_movie=False,
)
callback = SysIDCallback(simulator, visualizer)
# define logger
logger = BasicLogger(args=None, savedir= params['savedir'], verbosity=1, stdout=params['metrics'])
# select optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=params['lr'])

# define trainer
trainer = Trainer(
    model,
    train_data,
    dev_data,
    test_data,
    optimizer,
    callback=callback,
    logger=logger,
    epochs=params['epochs'],
    eval_metric=params['eval_metric'],
    patience=params['patience'],
    warmup=params['warmup'],
    device=device,
)
# Out:
# None
# Number of parameters: 85022

# %% [markdown]
# Now we enter the training loop by calling the `train()` method on the `trainer` object; upon training completion, this method will return the best-observed model according to the evaluation metric specified previously.

# %%
best_model = trainer.train()
# Out:
# epoch: 0	nstep_dev_ref_loss: 0.26927	nstep_dev_loss: 0.40783	loop_dev_ref_loss: 0.26931	loop_dev_loss: nan	eltime:  6.88360
# epoch: 1	nstep_dev_ref_loss: 0.24834	nstep_dev_loss: 0.29733	loop_dev_ref_loss: 0.24833	loop_dev_loss: nan	eltime:  6.96557
# epoch: 2	nstep_dev_ref_loss: 0.22960	nstep_dev_loss: 0.29481	loop_dev_ref_loss: 0.22957	loop_dev_loss: nan	eltime:  7.04627
# epoch: 3	nstep_dev_ref_loss: 0.21216	nstep_dev_loss: 0.30905	loop_dev_ref_loss: 0.21211	loop_dev_loss: nan	eltime:  7.12937
# epoch: 4	nstep_dev_ref_loss: 0.19604	nstep_dev_loss: 0.28609	loop_dev_ref_loss: 0.19599	loop_dev_loss: nan	eltime:  7.21185
# epoch: 23	nstep_dev_ref_loss: 0.14187	nstep_dev_loss: 0.20141	loop_dev_ref_loss: 0.14205	loop_dev_loss: nan	eltime:  8.75809
# epoch: 24	nstep_dev_ref_loss: 0.13702	nstep_dev_loss: 0.19976	loop_dev_ref_loss: 0.13707	loop_dev_loss: nan	eltime:  8.84049
# epoch: 25	nstep_dev_ref_loss: 0.13146	nstep_dev_loss: 0.19991	loop_dev_ref_loss: 0.13136	loop_dev_loss: nan	eltime:  8.92284
# epoch: 26	nstep_dev_ref_loss: 0.12788	nstep_dev_loss: 0.20369	loop_dev_ref_loss: 0.12769	loop_dev_loss: nan	eltime:  9.00320
# epoch: 27	nstep_dev_ref_loss: 0.12655	nstep_dev_loss: 0.20867	loop_dev_ref_loss: 0.12633	loop_dev_loss: nan	eltime:  9.08963
# epoch: 28	nstep_dev_ref_loss: 0.12558	nstep_dev_loss: 0.21244	loop_dev_ref_loss: 0.12538	loop_dev_loss: nan	eltime:  9.17242
# epoch: 29	nstep_dev_ref_loss: 0.12341	nstep_dev_loss: 0.21435	loop_dev_ref_loss: 0.12325	loop_dev_loss: nan	eltime:  9.25811
# epoch: 30	nstep_dev_ref_loss: 0.12147	nstep_dev_loss: 0.21383	loop_dev_ref_loss: 0.12139	loop_dev_loss: nan	eltime:  9.34267
# epoch: 31	nstep_dev_ref_loss: 0.12116	nstep_dev_loss: 0.21041	loop_dev_ref_loss: 0.12118	loop_dev_loss: nan	eltime:  9.42540
# epoch: 32	nstep_dev_ref_loss: 0.12255	nstep_dev_loss: 0.20734	loop_dev_ref_loss: 0.12268	loop_dev_loss: nan	eltime:  9.50542
# epoch: 33	nstep_dev_ref_loss: 0.12428	nstep_dev_loss: 0.20597	loop_dev_ref_loss: 0.12456	loop_dev_loss: nan	eltime:  9.58647
# epoch: 34	nstep_dev_ref_loss: 0.12504	nstep_dev_loss: 0.20446	loop_dev_ref_loss: 0.12542	loop_dev_loss: nan	eltime:  9.66661
# epoch: 35	nstep_dev_ref_loss: 0.12490	nstep_dev_loss: 0.20183	loop_dev_ref_loss: 0.12533	loop_dev_loss: nan	eltime:  9.74429
# epoch: 36	nstep_dev_ref_loss: 0.12437	nstep_dev_loss: 0.19832	loop_dev_ref_loss: 0.12483	loop_dev_loss: nan	eltime:  9.82473
# epoch: 37	nstep_dev_ref_loss: 0.12359	nstep_dev_loss: 0.19446	loop_dev_ref_loss: 0.12405	loop_dev_loss: nan	eltime:  9.90473
# epoch: 38	nstep_dev_ref_loss: 0.12224	nstep_dev_loss: 0.19026	loop_dev_ref_loss: 0.12268	loop_dev_loss: nan	eltime:  9.98346
# epoch: 39	nstep_dev_ref_loss: 0.11999	nstep_dev_loss: 0.18547	loop_dev_ref_loss: 0.12037	loop_dev_loss: nan	eltime:  10.06537
# epoch: 40	nstep_dev_ref_loss: 0.11701	nstep_dev_loss: 0.18033	loop_dev_ref_loss: 0.11732	loop_dev_loss: nan	eltime:  10.14500
# epoch: 41	nstep_dev_ref_loss: 0.11397	nstep_dev_loss: 0.17553	loop_dev_ref_loss: 0.11420	loop_dev_loss: nan	eltime:  10.22989
# epoch: 60	nstep_dev_ref_loss: 0.09142	nstep_dev_loss: 0.13731	loop_dev_ref_loss: 0.09142	loop_dev_loss: nan	eltime:  11.79730
# epoch: 61	nstep_dev_ref_loss: 0.09038	nstep_dev_loss: 0.13594	loop_dev_ref_loss: 0.09038	loop_dev_loss: nan	eltime:  11.87790
# epoch: 62	nstep_dev_ref_loss: 0.08917	nstep_dev_loss: 0.13445	loop_dev_ref_loss: 0.08916	loop_dev_loss: nan	eltime:  11.95977
# epoch: 63	nstep_dev_ref_loss: 0.08774	nstep_dev_loss: 0.13270	loop_dev_ref_loss: 0.08773	loop_dev_loss: nan	eltime:  12.04286
# epoch: 64	nstep_dev_ref_loss: 0.08623	nstep_dev_loss: 0.13090	loop_dev_ref_loss: 0.08620	loop_dev_loss: nan	eltime:  12.12272
# epoch: 65	nstep_dev_ref_loss: 0.08478	nstep_dev_loss: 0.12934	loop_dev_ref_loss: 0.08474	loop_dev_loss: nan	eltime:  12.20428
# epoch: 66	nstep_dev_ref_loss: 0.08341	nstep_dev_loss: 0.12806	loop_dev_ref_loss: 0.08336	loop_dev_loss: nan	eltime:  12.29267
# epoch: 67	nstep_dev_ref_loss: 0.08205	nstep_dev_loss: 0.12694	loop_dev_ref_loss: 0.08199	loop_dev_loss: nan	eltime:  12.37423
# epoch: 68	nstep_dev_ref_loss: 0.08066	nstep_dev_loss: 0.12586	loop_dev_ref_loss: 0.08059	loop_dev_loss: nan	eltime:  12.45477
# epoch: 69	nstep_dev_ref_loss: 0.07932	nstep_dev_loss: 0.12490	loop_dev_ref_loss: 0.07924	loop_dev_loss: nan	eltime:  12.53719
# epoch: 70	nstep_dev_ref_loss: 0.07814	nstep_dev_loss: 0.12421	loop_dev_ref_loss: 0.07806	loop_dev_loss: nan	eltime:  12.62220
# epoch: 71	nstep_dev_ref_loss: 0.07714	nstep_dev_loss: 0.12377	loop_dev_ref_loss: 0.07705	loop_dev_loss: nan	eltime:  12.70391
# epoch: 72	nstep_dev_ref_loss: 0.07622	nstep_dev_loss: 0.12341	loop_dev_ref_loss: 0.07613	loop_dev_loss: nan	eltime:  12.78646
# epoch: 73	nstep_dev_ref_loss: 0.07526	nstep_dev_loss: 0.12291	loop_dev_ref_loss: 0.07518	loop_dev_loss: nan	eltime:  12.86546
# epoch: 74	nstep_dev_ref_loss: 0.07433	nstep_dev_loss: 0.12235	loop_dev_ref_loss: 0.07425	loop_dev_loss: nan	eltime:  12.94445
# epoch: 75	nstep_dev_ref_loss: 0.07351	nstep_dev_loss: 0.12186	loop_dev_ref_loss: 0.07343	loop_dev_loss: nan	eltime:  13.02525
# epoch: 76	nstep_dev_ref_loss: 0.07279	nstep_dev_loss: 0.12147	loop_dev_ref_loss: 0.07272	loop_dev_loss: nan	eltime:  13.11009
# epoch: 77	nstep_dev_ref_loss: 0.07210	nstep_dev_loss: 0.12115	loop_dev_ref_loss: 0.07205	loop_dev_loss: nan	eltime:  13.19196
# epoch: 78	nstep_dev_ref_loss: 0.07146	nstep_dev_loss: 0.12095	loop_dev_ref_loss: 0.07142	loop_dev_loss: nan	eltime:  13.27401
# epoch: 135	nstep_dev_ref_loss: 0.07128	nstep_dev_loss: 0.13625	loop_dev_ref_loss: 0.07147	loop_dev_loss: nan	eltime:  18.04802
# epoch: 136	nstep_dev_ref_loss: 0.07112	nstep_dev_loss: 0.13600	loop_dev_ref_loss: 0.07131	loop_dev_loss: nan	eltime:  18.13572
# epoch: 137	nstep_dev_ref_loss: 0.07094	nstep_dev_loss: 0.13572	loop_dev_ref_loss: 0.07113	loop_dev_loss: nan	eltime:  18.22195
# epoch: 138	nstep_dev_ref_loss: 0.07077	nstep_dev_loss: 0.13545	loop_dev_ref_loss: 0.07095	loop_dev_loss: nan	eltime:  18.30504
# epoch: 139	nstep_dev_ref_loss: 0.07060	nstep_dev_loss: 0.13522	loop_dev_ref_loss: 0.07078	loop_dev_loss: nan	eltime:  18.38829
# epoch: 140	nstep_dev_ref_loss: 0.07044	nstep_dev_loss: 0.13496	loop_dev_ref_loss: 0.07061	loop_dev_loss: nan	eltime:  18.46860
# epoch: 141	nstep_dev_ref_loss: 0.07026	nstep_dev_loss: 0.13467	loop_dev_ref_loss: 0.07043	loop_dev_loss: nan	eltime:  18.55413
# epoch: 142	nstep_dev_ref_loss: 0.07010	nstep_dev_loss: 0.13442	loop_dev_ref_loss: 0.07026	loop_dev_loss: nan	eltime:  18.63832
# epoch: 143	nstep_dev_ref_loss: 0.06994	nstep_dev_loss: 0.13423	loop_dev_ref_loss: 0.07010	loop_dev_loss: nan	eltime:  18.72636
# epoch: 144	nstep_dev_ref_loss: 0.06978	nstep_dev_loss: 0.13402	loop_dev_ref_loss: 0.06993	loop_dev_loss: nan	eltime:  18.81458
# epoch: 145	nstep_dev_ref_loss: 0.06960	nstep_dev_loss: 0.13379	loop_dev_ref_loss: 0.06975	loop_dev_loss: nan	eltime:  18.90291
# epoch: 146	nstep_dev_ref_loss: 0.06943	nstep_dev_loss: 0.13360	loop_dev_ref_loss: 0.06957	loop_dev_loss: nan	eltime:  18.99015
# epoch: 147	nstep_dev_ref_loss: 0.06926	nstep_dev_loss: 0.13342	loop_dev_ref_loss: 0.06940	loop_dev_loss: nan	eltime:  19.07655
# epoch: 148	nstep_dev_ref_loss: 0.06908	nstep_dev_loss: 0.13322	loop_dev_ref_loss: 0.06922	loop_dev_loss: nan	eltime:  19.16132
# epoch: 149	nstep_dev_ref_loss: 0.06890	nstep_dev_loss: 0.13300	loop_dev_ref_loss: 0.06903	loop_dev_loss: nan	eltime:  19.24793
# epoch: 150	nstep_dev_ref_loss: 0.06871	nstep_dev_loss: 0.13276	loop_dev_ref_loss: 0.06884	loop_dev_loss: nan	eltime:  19.33252
# epoch: 151	nstep_dev_ref_loss: 0.06852	nstep_dev_loss: 0.13252	loop_dev_ref_loss: 0.06865	loop_dev_loss: nan	eltime:  19.43095
# epoch: 152	nstep_dev_ref_loss: 0.06834	nstep_dev_loss: 0.13229	loop_dev_ref_loss: 0.06845	loop_dev_loss: nan	eltime:  19.52038
# epoch: 153	nstep_dev_ref_loss: 0.06814	nstep_dev_loss: 0.13207	loop_dev_ref_loss: 0.06825	loop_dev_loss: nan	eltime:  19.60501
# epoch: 154	nstep_dev_ref_loss: 0.06795	nstep_dev_loss: 0.13186	loop_dev_ref_loss: 0.06806	loop_dev_loss: nan	eltime:  19.69174
# epoch: 155	nstep_dev_ref_loss: 0.06776	nstep_dev_loss: 0.13167	loop_dev_ref_loss: 0.06786	loop_dev_loss: nan	eltime:  19.78006
# epoch: 156	nstep_dev_ref_loss: 0.06756	nstep_dev_loss: 0.13146	loop_dev_ref_loss: 0.06766	loop_dev_loss: nan	eltime:  19.87241
# epoch: 157	nstep_dev_ref_loss: 0.06738	nstep_dev_loss: 0.13129	loop_dev_ref_loss: 0.06748	loop_dev_loss: nan	eltime:  19.95684
# epoch: 158	nstep_dev_ref_loss: 0.06719	nstep_dev_loss: 0.13107	loop_dev_ref_loss: 0.06728	loop_dev_loss: nan	eltime:  20.04126
# epoch: 159	nstep_dev_ref_loss: 0.06703	nstep_dev_loss: 0.13097	loop_dev_ref_loss: 0.06712	loop_dev_loss: nan	eltime:  20.12705
# epoch: 160	nstep_dev_ref_loss: 0.06686	nstep_dev_loss: 0.13082	loop_dev_ref_loss: 0.06694	loop_dev_loss: nan	eltime:  20.21908
# epoch: 161	nstep_dev_ref_loss: 0.06666	nstep_dev_loss: 0.13056	loop_dev_ref_loss: 0.06674	loop_dev_loss: nan	eltime:  20.31615
# epoch: 162	nstep_dev_ref_loss: 0.06649	nstep_dev_loss: 0.13043	loop_dev_ref_loss: 0.06657	loop_dev_loss: nan	eltime:  20.40714
# epoch: 163	nstep_dev_ref_loss: 0.06632	nstep_dev_loss: 0.13027	loop_dev_ref_loss: 0.06639	loop_dev_loss: nan	eltime:  20.49404
# epoch: 164	nstep_dev_ref_loss: 0.06613	nstep_dev_loss: 0.13004	loop_dev_ref_loss: 0.06620	loop_dev_loss: nan	eltime:  20.58137
# epoch: 165	nstep_dev_ref_loss: 0.06596	nstep_dev_loss: 0.12990	loop_dev_ref_loss: 0.06602	loop_dev_loss: nan	eltime:  20.67084
# epoch: 166	nstep_dev_ref_loss: 0.06579	nstep_dev_loss: 0.12973	loop_dev_ref_loss: 0.06585	loop_dev_loss: nan	eltime:  20.75589
# epoch: 167	nstep_dev_ref_loss: 0.06561	nstep_dev_loss: 0.12953	loop_dev_ref_loss: 0.06566	loop_dev_loss: nan	eltime:  20.83967
# epoch: 168	nstep_dev_ref_loss: 0.06545	nstep_dev_loss: 0.12942	loop_dev_ref_loss: 0.06550	loop_dev_loss: nan	eltime:  20.92598
# epoch: 169	nstep_dev_ref_loss: 0.06527	nstep_dev_loss: 0.12924	loop_dev_ref_loss: 0.06532	loop_dev_loss: nan	eltime:  21.01212
# epoch: 170	nstep_dev_ref_loss: 0.06509	nstep_dev_loss: 0.12902	loop_dev_ref_loss: 0.06513	loop_dev_loss: nan	eltime:  21.10084
# epoch: 171	nstep_dev_ref_loss: 0.06492	nstep_dev_loss: 0.12888	loop_dev_ref_loss: 0.06496	loop_dev_loss: nan	eltime:  21.18672
# epoch: 172	nstep_dev_ref_loss: 0.06474	nstep_dev_loss: 0.12868	loop_dev_ref_loss: 0.06477	loop_dev_loss: nan	eltime:  21.27182
# epoch: 173	nstep_dev_ref_loss: 0.06455	nstep_dev_loss: 0.12850	loop_dev_ref_loss: 0.06458	loop_dev_loss: nan	eltime:  21.35948
# epoch: 174	nstep_dev_ref_loss: 0.06437	nstep_dev_loss: 0.12833	loop_dev_ref_loss: 0.06439	loop_dev_loss: nan	eltime:  21.44477
# epoch: 175	nstep_dev_ref_loss: 0.06417	nstep_dev_loss: 0.12810	loop_dev_ref_loss: 0.06419	loop_dev_loss: nan	eltime:  21.52717
# epoch: 176	nstep_dev_ref_loss: 0.06398	nstep_dev_loss: 0.12792	loop_dev_ref_loss: 0.06399	loop_dev_loss: nan	eltime:  21.61080
# epoch: 177	nstep_dev_ref_loss: 0.06379	nstep_dev_loss: 0.12774	loop_dev_ref_loss: 0.06380	loop_dev_loss: nan	eltime:  21.69896
# epoch: 178	nstep_dev_ref_loss: 0.06358	nstep_dev_loss: 0.12751	loop_dev_ref_loss: 0.06359	loop_dev_loss: nan	eltime:  21.78255
# epoch: 179	nstep_dev_ref_loss: 0.06340	nstep_dev_loss: 0.12734	loop_dev_ref_loss: 0.06341	loop_dev_loss: nan	eltime:  21.86559
# epoch: 180	nstep_dev_ref_loss: 0.06321	nstep_dev_loss: 0.12714	loop_dev_ref_loss: 0.06321	loop_dev_loss: nan	eltime:  21.94965
# epoch: 181	nstep_dev_ref_loss: 0.06302	nstep_dev_loss: 0.12694	loop_dev_ref_loss: 0.06302	loop_dev_loss: nan	eltime:  22.03510
# epoch: 182	nstep_dev_ref_loss: 0.06283	nstep_dev_loss: 0.12678	loop_dev_ref_loss: 0.06282	loop_dev_loss: nan	eltime:  22.12259
# epoch: 183	nstep_dev_ref_loss: 0.06264	nstep_dev_loss: 0.12657	loop_dev_ref_loss: 0.06263	loop_dev_loss: nan	eltime:  22.21101
# epoch: 184	nstep_dev_ref_loss: 0.06246	nstep_dev_loss: 0.12640	loop_dev_ref_loss: 0.06244	loop_dev_loss: nan	eltime:  22.29460
# epoch: 185	nstep_dev_ref_loss: 0.06227	nstep_dev_loss: 0.12623	loop_dev_ref_loss: 0.06225	loop_dev_loss: nan	eltime:  22.37562
# epoch: 186	nstep_dev_ref_loss: 0.06208	nstep_dev_loss: 0.12603	loop_dev_ref_loss: 0.06205	loop_dev_loss: nan	eltime:  22.45990
# epoch: 187	nstep_dev_ref_loss: 0.06189	nstep_dev_loss: 0.12586	loop_dev_ref_loss: 0.06185	loop_dev_loss: nan	eltime:  22.54233
# epoch: 188	nstep_dev_ref_loss: 0.06170	nstep_dev_loss: 0.12568	loop_dev_ref_loss: 0.06166	loop_dev_loss: nan	eltime:  22.63179
# epoch: 189	nstep_dev_ref_loss: 0.06152	nstep_dev_loss: 0.12550	loop_dev_ref_loss: 0.06148	loop_dev_loss: nan	eltime:  22.72267
# epoch: 190	nstep_dev_ref_loss: 0.06134	nstep_dev_loss: 0.12535	loop_dev_ref_loss: 0.06130	loop_dev_loss: nan	eltime:  22.80871
# epoch: 191	nstep_dev_ref_loss: 0.06115	nstep_dev_loss: 0.12514	loop_dev_ref_loss: 0.06110	loop_dev_loss: nan	eltime:  22.89402
# epoch: 192	nstep_dev_ref_loss: 0.06096	nstep_dev_loss: 0.12497	loop_dev_ref_loss: 0.06091	loop_dev_loss: nan	eltime:  22.97789
# epoch: 193	nstep_dev_ref_loss: 0.06078	nstep_dev_loss: 0.12482	loop_dev_ref_loss: 0.06071	loop_dev_loss: nan	eltime:  23.05812
# epoch: 194	nstep_dev_ref_loss: 0.06059	nstep_dev_loss: 0.12461	loop_dev_ref_loss: 0.06052	loop_dev_loss: nan	eltime:  23.14144
# epoch: 195	nstep_dev_ref_loss: 0.06042	nstep_dev_loss: 0.12452	loop_dev_ref_loss: 0.06035	loop_dev_loss: nan	eltime:  23.22723
# epoch: 196	nstep_dev_ref_loss: 0.06023	nstep_dev_loss: 0.12434	loop_dev_ref_loss: 0.06016	loop_dev_loss: nan	eltime:  23.31719
# epoch: 197	nstep_dev_ref_loss: 0.06006	nstep_dev_loss: 0.12417	loop_dev_ref_loss: 0.05998	loop_dev_loss: nan	eltime:  23.40100
# epoch: 198	nstep_dev_ref_loss: 0.05987	nstep_dev_loss: 0.12402	loop_dev_ref_loss: 0.05978	loop_dev_loss: nan	eltime:  23.48928
# epoch: 199	nstep_dev_ref_loss: 0.05967	nstep_dev_loss: 0.12381	loop_dev_ref_loss: 0.05958	loop_dev_loss: nan	eltime:  23.57600
# epoch: 200	nstep_dev_ref_loss: 0.05950	nstep_dev_loss: 0.12373	loop_dev_ref_loss: 0.05941	loop_dev_loss: nan	eltime:  23.65996
# epoch: 201	nstep_dev_ref_loss: 0.05931	nstep_dev_loss: 0.12354	loop_dev_ref_loss: 0.05921	loop_dev_loss: nan	eltime:  23.74395
# epoch: 202	nstep_dev_ref_loss: 0.05914	nstep_dev_loss: 0.12340	loop_dev_ref_loss: 0.05903	loop_dev_loss: nan	eltime:  23.82947
# epoch: 203	nstep_dev_ref_loss: 0.05896	nstep_dev_loss: 0.12330	loop_dev_ref_loss: 0.05885	loop_dev_loss: nan	eltime:  23.91774
# epoch: 204	nstep_dev_ref_loss: 0.05877	nstep_dev_loss: 0.12308	loop_dev_ref_loss: 0.05865	loop_dev_loss: nan	eltime:  24.00880
# epoch: 205	nstep_dev_ref_loss: 0.05859	nstep_dev_loss: 0.12298	loop_dev_ref_loss: 0.05847	loop_dev_loss: nan	eltime:  24.09837
# epoch: 206	nstep_dev_ref_loss: 0.05839	nstep_dev_loss: 0.12274	loop_dev_ref_loss: 0.05827	loop_dev_loss: nan	eltime:  24.18566
# epoch: 207	nstep_dev_ref_loss: 0.05822	nstep_dev_loss: 0.12269	loop_dev_ref_loss: 0.05809	loop_dev_loss: nan	eltime:  24.27431
# epoch: 208	nstep_dev_ref_loss: 0.05803	nstep_dev_loss: 0.12254	loop_dev_ref_loss: 0.05789	loop_dev_loss: nan	eltime:  24.35857
# epoch: 209	nstep_dev_ref_loss: 0.05785	nstep_dev_loss: 0.12236	loop_dev_ref_loss: 0.05771	loop_dev_loss: nan	eltime:  24.45028
# epoch: 210	nstep_dev_ref_loss: 0.05767	nstep_dev_loss: 0.12227	loop_dev_ref_loss: 0.05753	loop_dev_loss: nan	eltime:  24.55148
# epoch: 211	nstep_dev_ref_loss: 0.05747	nstep_dev_loss: 0.12209	loop_dev_ref_loss: 0.05731	loop_dev_loss: nan	eltime:  24.64624
# epoch: 212	nstep_dev_ref_loss: 0.05729	nstep_dev_loss: 0.12198	loop_dev_ref_loss: 0.05714	loop_dev_loss: nan	eltime:  24.73021
# epoch: 213	nstep_dev_ref_loss: 0.05709	nstep_dev_loss: 0.12178	loop_dev_ref_loss: 0.05693	loop_dev_loss: nan	eltime:  24.81079
# epoch: 214	nstep_dev_ref_loss: 0.05692	nstep_dev_loss: 0.12173	loop_dev_ref_loss: 0.05675	loop_dev_loss: nan	eltime:  24.88933
# epoch: 215	nstep_dev_ref_loss: 0.05673	nstep_dev_loss: 0.12158	loop_dev_ref_loss: 0.05656	loop_dev_loss: nan	eltime:  24.97831
# epoch: 216	nstep_dev_ref_loss: 0.05654	nstep_dev_loss: 0.12139	loop_dev_ref_loss: 0.05637	loop_dev_loss: nan	eltime:  25.06454
# epoch: 217	nstep_dev_ref_loss: 0.05635	nstep_dev_loss: 0.12131	loop_dev_ref_loss: 0.05617	loop_dev_loss: nan	eltime:  25.14505
# epoch: 218	nstep_dev_ref_loss: 0.05615	nstep_dev_loss: 0.12115	loop_dev_ref_loss: 0.05596	loop_dev_loss: nan	eltime:  25.22574
# epoch: 219	nstep_dev_ref_loss: 0.05598	nstep_dev_loss: 0.12107	loop_dev_ref_loss: 0.05579	loop_dev_loss: nan	eltime:  25.30922
# epoch: 220	nstep_dev_ref_loss: 0.05578	nstep_dev_loss: 0.12087	loop_dev_ref_loss: 0.05558	loop_dev_loss: nan	eltime:  25.39087
# epoch: 221	nstep_dev_ref_loss: 0.05561	nstep_dev_loss: 0.12087	loop_dev_ref_loss: 0.05541	loop_dev_loss: nan	eltime:  25.47178
# epoch: 222	nstep_dev_ref_loss: 0.05541	nstep_dev_loss: 0.12065	loop_dev_ref_loss: 0.05520	loop_dev_loss: nan	eltime:  25.55528
# epoch: 223	nstep_dev_ref_loss: 0.05524	nstep_dev_loss: 0.12057	loop_dev_ref_loss: 0.05502	loop_dev_loss: nan	eltime:  25.63808
# epoch: 224	nstep_dev_ref_loss: 0.05502	nstep_dev_loss: 0.12036	loop_dev_ref_loss: 0.05480	loop_dev_loss: nan	eltime:  25.72224
# epoch: 225	nstep_dev_ref_loss: 0.05486	nstep_dev_loss: 0.12039	loop_dev_ref_loss: 0.05463	loop_dev_loss: nan	eltime:  25.80891
# epoch: 226	nstep_dev_ref_loss: 0.05465	nstep_dev_loss: 0.12011	loop_dev_ref_loss: 0.05441	loop_dev_loss: nan	eltime:  25.89320
# epoch: 227	nstep_dev_ref_loss: 0.05449	nstep_dev_loss: 0.12018	loop_dev_ref_loss: 0.05426	loop_dev_loss: nan	eltime:  25.98079
# epoch: 228	nstep_dev_ref_loss: 0.05427	nstep_dev_loss: 0.11989	loop_dev_ref_loss: 0.05402	loop_dev_loss: nan	eltime:  26.06786
# epoch: 229	nstep_dev_ref_loss: 0.05413	nstep_dev_loss: 0.12004	loop_dev_ref_loss: 0.05388	loop_dev_loss: nan	eltime:  26.15131
# epoch: 230	nstep_dev_ref_loss: 0.05387	nstep_dev_loss: 0.11952	loop_dev_ref_loss: 0.05361	loop_dev_loss: nan	eltime:  26.23687
# epoch: 231	nstep_dev_ref_loss: 0.05377	nstep_dev_loss: 0.11999	loop_dev_ref_loss: 0.05351	loop_dev_loss: nan	eltime:  26.32251
# epoch: 232	nstep_dev_ref_loss: 0.05345	nstep_dev_loss: 0.11913	loop_dev_ref_loss: 0.05317	loop_dev_loss: nan	eltime:  26.40570
# epoch: 233	nstep_dev_ref_loss: 0.05345	nstep_dev_loss: 0.12007	loop_dev_ref_loss: 0.05319	loop_dev_loss: nan	eltime:  26.49030
# epoch: 234	nstep_dev_ref_loss: 0.05299	nstep_dev_loss: 0.11847	loop_dev_ref_loss: 0.05270	loop_dev_loss: nan	eltime:  26.57565
# epoch: 235	nstep_dev_ref_loss: 0.05317	nstep_dev_loss: 0.12038	loop_dev_ref_loss: 0.05290	loop_dev_loss: nan	eltime:  26.66159
# epoch: 236	nstep_dev_ref_loss: 0.05251	nstep_dev_loss: 0.11769	loop_dev_ref_loss: 0.05219	loop_dev_loss: nan	eltime:  26.74377
# epoch: 237	nstep_dev_ref_loss: 0.05288	nstep_dev_loss: 0.12051	loop_dev_ref_loss: 0.05261	loop_dev_loss: nan	eltime:  26.82515
# epoch: 238	nstep_dev_ref_loss: 0.05211	nstep_dev_loss: 0.11717	loop_dev_ref_loss: 0.05177	loop_dev_loss: nan	eltime:  26.90710
# epoch: 239	nstep_dev_ref_loss: 0.05241	nstep_dev_loss: 0.11965	loop_dev_ref_loss: 0.05212	loop_dev_loss: nan	eltime:  26.98599
# epoch: 240	nstep_dev_ref_loss: 0.05185	nstep_dev_loss: 0.11753	loop_dev_ref_loss: 0.05151	loop_dev_loss: nan	eltime:  27.06855
# epoch: 241	nstep_dev_ref_loss: 0.05177	nstep_dev_loss: 0.11797	loop_dev_ref_loss: 0.05144	loop_dev_loss: nan	eltime:  27.15147
# epoch: 242	nstep_dev_ref_loss: 0.05173	nstep_dev_loss: 0.11862	loop_dev_ref_loss: 0.05140	loop_dev_loss: nan	eltime:  27.23420
# epoch: 243	nstep_dev_ref_loss: 0.05125	nstep_dev_loss: 0.11687	loop_dev_ref_loss: 0.05088	loop_dev_loss: nan	eltime:  27.31668
# epoch: 244	nstep_dev_ref_loss: 0.05146	nstep_dev_loss: 0.11894	loop_dev_ref_loss: 0.05113	loop_dev_loss: nan	eltime:  27.39730
# epoch: 245	nstep_dev_ref_loss: 0.05091	nstep_dev_loss: 0.11680	loop_dev_ref_loss: 0.05053	loop_dev_loss: nan	eltime:  27.48240
# epoch: 246	nstep_dev_ref_loss: 0.05093	nstep_dev_loss: 0.11785	loop_dev_ref_loss: 0.05058	loop_dev_loss: nan	eltime:  27.56773
# epoch: 247	nstep_dev_ref_loss: 0.05070	nstep_dev_loss: 0.11749	loop_dev_ref_loss: 0.05034	loop_dev_loss: nan	eltime:  27.65415
# epoch: 248	nstep_dev_ref_loss: 0.05041	nstep_dev_loss: 0.11672	loop_dev_ref_loss: 0.05003	loop_dev_loss: nan	eltime:  27.74305
# epoch: 249	nstep_dev_ref_loss: 0.05049	nstep_dev_loss: 0.11807	loop_dev_ref_loss: 0.05013	loop_dev_loss: nan	eltime:  27.83055
# epoch: 250	nstep_dev_ref_loss: 0.05003	nstep_dev_loss: 0.11636	loop_dev_ref_loss: 0.04963	loop_dev_loss: nan	eltime:  27.91902
# epoch: 251	nstep_dev_ref_loss: 0.05012	nstep_dev_loss: 0.11787	loop_dev_ref_loss: 0.04974	loop_dev_loss: nan	eltime:  27.99820
# epoch: 252	nstep_dev_ref_loss: 0.04976	nstep_dev_loss: 0.11688	loop_dev_ref_loss: 0.04936	loop_dev_loss: nan	eltime:  28.08117
# epoch: 253	nstep_dev_ref_loss: 0.04964	nstep_dev_loss: 0.11711	loop_dev_ref_loss: 0.04923	loop_dev_loss: nan	eltime:  28.16623
# epoch: 254	nstep_dev_ref_loss: 0.04955	nstep_dev_loss: 0.11758	loop_dev_ref_loss: 0.04916	loop_dev_loss: nan	eltime:  28.25538
# epoch: 255	nstep_dev_ref_loss: 0.04921	nstep_dev_loss: 0.11657	loop_dev_ref_loss: 0.04879	loop_dev_loss: nan	eltime:  28.34253
# epoch: 256	nstep_dev_ref_loss: 0.04926	nstep_dev_loss: 0.11785	loop_dev_ref_loss: 0.04886	loop_dev_loss: nan	eltime:  28.42778
# epoch: 257	nstep_dev_ref_loss: 0.04885	nstep_dev_loss: 0.11640	loop_dev_ref_loss: 0.04841	loop_dev_loss: nan	eltime:  28.51518
# epoch: 258	nstep_dev_ref_loss: 0.04888	nstep_dev_loss: 0.11758	loop_dev_ref_loss: 0.04846	loop_dev_loss: nan	eltime:  28.60431
# epoch: 259	nstep_dev_ref_loss: 0.04853	nstep_dev_loss: 0.11658	loop_dev_ref_loss: 0.04809	loop_dev_loss: nan	eltime:  28.69083
# epoch: 260	nstep_dev_ref_loss: 0.04843	nstep_dev_loss: 0.11703	loop_dev_ref_loss: 0.04799	loop_dev_loss: nan	eltime:  28.77251
# epoch: 261	nstep_dev_ref_loss: 0.04823	nstep_dev_loss: 0.11691	loop_dev_ref_loss: 0.04779	loop_dev_loss: nan	eltime:  28.85847
# epoch: 262	nstep_dev_ref_loss: 0.04800	nstep_dev_loss: 0.11655	loop_dev_ref_loss: 0.04754	loop_dev_loss: nan	eltime:  28.94120
# epoch: 263	nstep_dev_ref_loss: 0.04792	nstep_dev_loss: 0.11716	loop_dev_ref_loss: 0.04747	loop_dev_loss: nan	eltime:  29.02766
# epoch: 264	nstep_dev_ref_loss: 0.04759	nstep_dev_loss: 0.11619	loop_dev_ref_loss: 0.04711	loop_dev_loss: nan	eltime:  29.10885
# epoch: 265	nstep_dev_ref_loss: 0.04758	nstep_dev_loss: 0.11725	loop_dev_ref_loss: 0.04712	loop_dev_loss: nan	eltime:  29.19019
# epoch: 266	nstep_dev_ref_loss: 0.04719	nstep_dev_loss: 0.11583	loop_dev_ref_loss: 0.04669	loop_dev_loss: nan	eltime:  29.27604
# epoch: 267	nstep_dev_ref_loss: 0.04723	nstep_dev_loss: 0.11722	loop_dev_ref_loss: 0.04675	loop_dev_loss: nan	eltime:  29.35830
# epoch: 268	nstep_dev_ref_loss: 0.04680	nstep_dev_loss: 0.11555	loop_dev_ref_loss: 0.04629	loop_dev_loss: nan	eltime:  29.44142
# epoch: 269	nstep_dev_ref_loss: 0.04687	nstep_dev_loss: 0.11718	loop_dev_ref_loss: 0.04638	loop_dev_loss: nan	eltime:  29.53264
# epoch: 270	nstep_dev_ref_loss: 0.04640	nstep_dev_loss: 0.11522	loop_dev_ref_loss: 0.04587	loop_dev_loss: nan	eltime:  29.61842
# epoch: 271	nstep_dev_ref_loss: 0.04649	nstep_dev_loss: 0.11706	loop_dev_ref_loss: 0.04599	loop_dev_loss: nan	eltime:  29.70554
# epoch: 272	nstep_dev_ref_loss: 0.04601	nstep_dev_loss: 0.11487	loop_dev_ref_loss: 0.04546	loop_dev_loss: nan	eltime:  29.78901
# epoch: 273	nstep_dev_ref_loss: 0.04613	nstep_dev_loss: 0.11694	loop_dev_ref_loss: 0.04562	loop_dev_loss: nan	eltime:  29.87210
# epoch: 274	nstep_dev_ref_loss: 0.04562	nstep_dev_loss: 0.11450	loop_dev_ref_loss: 0.04506	loop_dev_loss: nan	eltime:  29.95566
# epoch: 275	nstep_dev_ref_loss: 0.04575	nstep_dev_loss: 0.11666	loop_dev_ref_loss: 0.04522	loop_dev_loss: nan	eltime:  30.03643
# epoch: 276	nstep_dev_ref_loss: 0.04527	nstep_dev_loss: 0.11427	loop_dev_ref_loss: 0.04469	loop_dev_loss: nan	eltime:  30.12105
# epoch: 277	nstep_dev_ref_loss: 0.04536	nstep_dev_loss: 0.11619	loop_dev_ref_loss: 0.04481	loop_dev_loss: nan	eltime:  30.20957
# epoch: 278	nstep_dev_ref_loss: 0.04492	nstep_dev_loss: 0.11420	loop_dev_ref_loss: 0.04433	loop_dev_loss: nan	eltime:  30.30469
# epoch: 279	nstep_dev_ref_loss: 0.04493	nstep_dev_loss: 0.11557	loop_dev_ref_loss: 0.04436	loop_dev_loss: nan	eltime:  30.38734
# epoch: 280	nstep_dev_ref_loss: 0.04462	nstep_dev_loss: 0.11442	loop_dev_ref_loss: 0.04403	loop_dev_loss: nan	eltime:  30.47045
# epoch: 281	nstep_dev_ref_loss: 0.04453	nstep_dev_loss: 0.11500	loop_dev_ref_loss: 0.04394	loop_dev_loss: nan	eltime:  30.55752
# epoch: 282	nstep_dev_ref_loss: 0.04432	nstep_dev_loss: 0.11478	loop_dev_ref_loss: 0.04372	loop_dev_loss: nan	eltime:  30.64523
# epoch: 283	nstep_dev_ref_loss: 0.04412	nstep_dev_loss: 0.11459	loop_dev_ref_loss: 0.04351	loop_dev_loss: nan	eltime:  30.73036
# epoch: 284	nstep_dev_ref_loss: 0.04401	nstep_dev_loss: 0.11514	loop_dev_ref_loss: 0.04341	loop_dev_loss: nan	eltime:  30.81708
# epoch: 285	nstep_dev_ref_loss: 0.04375	nstep_dev_loss: 0.11430	loop_dev_ref_loss: 0.04312	loop_dev_loss: nan	eltime:  30.90723
# epoch: 286	nstep_dev_ref_loss: 0.04371	nstep_dev_loss: 0.11552	loop_dev_ref_loss: 0.04310	loop_dev_loss: nan	eltime:  30.99898
# epoch: 287	nstep_dev_ref_loss: 0.04336	nstep_dev_loss: 0.11395	loop_dev_ref_loss: 0.04271	loop_dev_loss: nan	eltime:  31.09236
# epoch: 288	nstep_dev_ref_loss: 0.04343	nstep_dev_loss: 0.11602	loop_dev_ref_loss: 0.04282	loop_dev_loss: nan	eltime:  31.18882
# epoch: 289	nstep_dev_ref_loss: 0.04299	nstep_dev_loss: 0.11337	loop_dev_ref_loss: 0.04232	loop_dev_loss: nan	eltime:  31.27258
# epoch: 290	nstep_dev_ref_loss: 0.04318	nstep_dev_loss: 0.11654	loop_dev_ref_loss: 0.04257	loop_dev_loss: nan	eltime:  31.35084
# epoch: 291	nstep_dev_ref_loss: 0.04260	nstep_dev_loss: 0.11226	loop_dev_ref_loss: 0.04190	loop_dev_loss: nan	eltime:  31.43173
# epoch: 292	nstep_dev_ref_loss: 0.04289	nstep_dev_loss: 0.11639	loop_dev_ref_loss: 0.04228	loop_dev_loss: nan	eltime:  31.51091
# epoch: 293	nstep_dev_ref_loss: 0.04225	nstep_dev_loss: 0.11116	loop_dev_ref_loss: 0.04154	loop_dev_loss: nan	eltime:  31.59252
# epoch: 294	nstep_dev_ref_loss: 0.04237	nstep_dev_loss: 0.11403	loop_dev_ref_loss: 0.04172	loop_dev_loss: nan	eltime:  31.67579
# epoch: 295	nstep_dev_ref_loss: 0.04204	nstep_dev_loss: 0.11169	loop_dev_ref_loss: 0.04135	loop_dev_loss: nan	eltime:  31.75619
# epoch: 296	nstep_dev_ref_loss: 0.04188	nstep_dev_loss: 0.11096	loop_dev_ref_loss: 0.04117	loop_dev_loss: nan	eltime:  31.83892
# epoch: 297	nstep_dev_ref_loss: 0.04191	nstep_dev_loss: 0.11291	loop_dev_ref_loss: 0.04124	loop_dev_loss: nan	eltime:  31.92259
# epoch: 298	nstep_dev_ref_loss: 0.04154	nstep_dev_loss: 0.10992	loop_dev_ref_loss: 0.04081	loop_dev_loss: nan	eltime:  32.00358
# epoch: 299	nstep_dev_ref_loss: 0.04148	nstep_dev_loss: 0.11152	loop_dev_ref_loss: 0.04078	loop_dev_loss: nan	eltime:  32.08439

# %% [markdown]
# ## Model Evaluation
# Once training has concluded and the best model has been returned by the trainer, we can call the `evaluate()` method with the best model to evaluate the model's $N$-step and open-loop performance and use the visualizer to generate trace plots for both.
#
# Below, the model's $N$-step traces (top) and open-loop (bottom) traces are shown.

# %%
best_outputs = trainer.test(best_model)
# Out:
# epoch: 299	best_loop_dev_loss: nan	eltime:  56.21613

# %%
logger.clean_up()
